# %%
import pandas as pd
from pygam import GammaGAM, LogisticGAM, s, te, l
from GDPGAM_module import *
from scipy.stats import gamma
import numpy as np

# %% [markdown]
# Load data for both weather stations and mean temperature

# %%
weather_df = pd.read_csv('processed_data/weather_data_filled_1950_2023.csv.gz', sep=',', compression='gzip', encoding='utf-8', low_memory=False)
temp_df = pd.read_csv('processed_data/basin_wide_temperature_covariate.csv.gz', sep=',', compression='gzip', encoding='utf-8', low_memory=False, header=0)

# 2. Process Basin Temperature (30-day rolling window ending at time t)
temp_df.columns = ['Date', 'Basin_Mean_Temp']  # Enforce correct names
temp_df['Date'] = pd.to_datetime(temp_df['Date'])
temp_df = temp_df.sort_values('Date').set_index('Date')
temp_df['temp_30d_avg'] = temp_df['Basin_Mean_Temp'].rolling('30D').mean()
temp_df = temp_df.reset_index()


model_df = weather_df.copy()
# Ensure date format
if 'Date' not in model_df.columns:
        model_df['Date'] = pd.to_datetime(model_df['year'] * 1000 + model_df['day_of_year'], format='%Y%j')

# Merge and Drop NaNs
model_df = model_df.merge(temp_df[['Date', 'temp_30d_avg']], on='Date', how='inner')
model_df = model_df.dropna(subset=['RR', 'temp_30d_avg', 'ALTI', 'LON', 'LAT'])

# %% [markdown]
# ### Fit gamma GAM

# %%
X = model_df[['LON', 'LAT', 'ALTI', 'day_of_year', 'temp_30d_avg']].values
y = model_df['RR'].values

mask_extremes = y > 10
X_train = X[mask_extremes]
y_train = y[mask_extremes]

print(f"Data reduced from {len(y)} to {len(y_train)} rows (keeping > 10mm only).")

# --- STEP 1: GAMMA MODEL (The Bulk) ---
print("Fitting Step 1: Gamma GAM...")

# Using slightly fewer splines (8 vs 10) in tensor product for speed
gam_gamma = GammaGAM(te(0, 1, n_splines=8) + 
                        s(2, n_splines=8) + 
                        s(3, basis='cp', n_splines=10) + 
                        l(4)).fit(X_train, y_train)

# Predict mean for the subset (to calculate threshold u)
mean_pred = gam_gamma.predict(X_train)
shape_param = 1 / gam_gamma.distribution.scale 
scale_params = mean_pred / shape_param

# Calculate 90% quantile threshold u for the training set
u_thresholds = gamma.ppf(0.90, a=shape_param, scale=scale_params)

# We must store u in the dataframe (but only for the rows we kept)
model_df.loc[mask_extremes, 'threshold_u'] = u_thresholds
# Out:
# Data reduced from 5641423 to 294648 rows (keeping > 10mm only).
# Fitting Step 1: Gamma GAM...

# %%
plot_gamma_gam(gam_gamma)

# %% [markdown]
# ### Fit logistic GAM

# %%
print("Fitting Step 2: Logistic GAM...")
is_exceedance = (y_train > u_thresholds).astype(int)

gam_logit = LogisticGAM(te(0, 1, n_splines=8) + 
                        s(2, n_splines=8) + 
                        s(3, basis='cp', n_splines=10) + 
                        l(4)).fit(X_train, is_exceedance)

# additionnal info
model_df.loc[mask_extremes, 'prob_exceedance'] = gam_logit.predict_proba(X_train)
model_df['excess_over_threshold'] = np.where(
    (model_df['RR'] > model_df['threshold_u']) & (model_df['threshold_u'].notna()),
    model_df['RR'] - model_df['threshold_u'],
    np.nan
)
# Out:
# Fitting Step 2: Logistic GAM...

# %%
plot_logistic_gam(gam_logit)

# %% [markdown]
# ### Fit GDP GAM

# %%
print("Running GPDGAM with learnable xi...")

# Filter data
mask_gpd = model_df['excess_over_threshold'] > 0
df_gpd = model_df.loc[mask_gpd].copy()

X_gpd = df_gpd[['LON', 'LAT', 'ALTI', 'day_of_year', 'temp_30d_avg']].values
# NOTE: Use RAW excesses (mm) here, not normalized
y_gpd = df_gpd['excess_over_threshold'].values 

# Instantiate
gam_gpd = GPDGAM(
    te(0, 1, n_splines=8) + 
    s(2, n_splines=8) + 
    s(3, basis='cp', n_splines=10) + 
    l(4)
)

# Fit (Learns beta AND xi)
gam_gpd.fit(X_gpd, y_gpd)

# Predict Sigma
model_df.loc[mask_gpd, 'gpd_scale_sigma'] = gam_gpd.predict(X_gpd, type='scale')
model_df['gpd_shape_xi'] = gam_gpd.shape_xi_
# Out:
# Running GPDGAM with learnable xi...
# Starting Profile Likelihood Optimization (Initial xi=0.1)
# Iter 1: Updated xi from 0.1000 to 0.0282 (Diff: 7.1767e-02)
# Iter 2: Updated xi from 0.0282 to 0.0282 (Diff: 0.0000e+00)
# Convergence reached.

# %%
check_gpd_fit(gam_gpd, y_gpd, X_gpd)

# %%
rl_data = plot_return_levels(weather_df, temp_df, gam_gamma, gam_logit, gam_gpd)
# Out:
# Generating Figure 6: Seasonal Return Levels...
# Target stations [110, 478] not found. Using Station 36186001 instead.
# Predicting daily parameters...
# Plotting...

# %% [markdown]
# # Spatial modeling

# %% [markdown]
# ### Transform Margins to Unit Pareto Scale

# %%
import numpy as np
from scipy.stats import gamma

X_full = model_df[['LON', 'LAT', 'ALTI', 'day_of_year', 'temp_30d_avg']].values

# A. Gamma (Bulk) Parameters
mu_gamma = gam_gamma.predict(X_full)
shape_gamma = 1 / gam_gamma.distribution.scale
scale_gamma = mu_gamma / shape_gamma

# B. Threshold & Probability
model_df['u_hat'] = gamma.ppf(0.90, a=shape_gamma, scale=scale_gamma)
model_df['p_hat'] = gam_logit.predict_proba(X_full)

# C. GPD Parameters
model_df['sigma_hat'] = gam_gpd.predict(X_full, type='scale')
xi_val = gam_gpd.distribution.xi

# Apply Probability Integral Transform (PIT) with GLUING correction

# Mask for Tail vs Bulk
is_tail = model_df['RR'] > model_df['u_hat']
is_bulk = ~is_tail

# --- A. Tail Transformation (GPD Survival Function) ---
# For the tail, we use the standard GPD survival formula starting from p_hat
y_tail = model_df.loc[is_tail, 'RR']
u_tail = model_df.loc[is_tail, 'u_hat']
sigma_tail = model_df.loc[is_tail, 'sigma_hat']
p_tail = model_df.loc[is_tail, 'p_hat']

term = 1 + xi_val * (y_tail - u_tail) / sigma_tail
model_df.loc[is_tail, 'Y_pareto'] = (1 / p_tail) * (term ** (1 / xi_val))

# --- B. Bulk Transformation (Renormalized Gamma CDF) ---
# We must scale the Gamma CDF so it ends exactly at (1 - p_hat) at the threshold u_hat

# 1. Inputs for Gamma (Shifted if trained on RR-10)
y_bulk_shifted = np.maximum(model_df.loc[is_bulk, 'RR'] - 10, 0)
u_bulk_shifted = np.maximum(model_df.loc[is_bulk, 'u_hat'] - 10, 0) # The "limit" of the bulk

# 2. Compute CDFs
F_obs = gamma.cdf(y_bulk_shifted, a=shape_gamma, scale=scale_gamma[is_bulk])
F_u = gamma.cdf(u_bulk_shifted, a=shape_gamma, scale=scale_gamma[is_bulk])

# 3. Calculate Scaling Factor (The Fix)
# We map the range [0, F_u] -> [0, 1 - p_hat]
# This forces the Bulk curve to meet the Tail curve seamlessly
p_bulk = model_df.loc[is_bulk, 'p_hat']
scaling_factor = (1 - p_bulk) / F_u

# 4. Apply Scaling
F_total = F_obs * scaling_factor

# 5. Transform to Unit Pareto: Z = 1 / (1 - F_total)
# Clip F_total slightly < 1 to avoid division by zero
F_total = np.clip(F_total, 0, 1.0 - 1e-8)
model_df.loc[is_bulk, 'Y_pareto'] = 1 / (1 - F_total)

# Handle cases <= 10mm (if strictly censored)
# Force them to 1.0 (min Pareto value)
model_df.loc[model_df['RR'] <= 10, 'Y_pareto'] = 1.0

print("Data transformed to Unit Pareto scale (Continuity Correction Applied).")
print(model_df[['Date', 'RR', 'Y_pareto']].head())
# Out:
# Data transformed to Unit Pareto scale (Continuity Correction Applied).
#         Date   RR  Y_pareto
# 0 1950-01-01  0.0       1.0
# 1 1950-01-02  1.6       1.0
# 2 1950-01-03  5.4       1.0
# 3 1950-01-04  2.0       1.0
# 4 1950-01-05  1.9       1.0

# %%
import matplotlib.pyplot as plt
import numpy as np

def debug_pareto_transform(model_df):
    plt.figure(figsize=(14, 4))

    # --- Plot 1: The Transformation Curve (Rain vs Pareto) ---
    plt.subplot(1, 2, 1)
    
    # Subsample for speed if needed
    subset = model_df.sample(n=min(10000, len(model_df)))
    
    # Color by model source
    is_tail = subset['RR'] > subset['u_hat']
    
    plt.scatter(subset.loc[~is_tail, 'RR'], subset.loc[~is_tail, 'Y_pareto'], 
                alpha=0.3, s=10, c='blue', label='Bulk (Gamma)')
    plt.scatter(subset.loc[is_tail, 'RR'], subset.loc[is_tail, 'Y_pareto'], 
                alpha=0.5, s=10, c='red', label='Tail (GPD)')
    
    # Add vertical line for hard threshold
    plt.axvline(10, color='black', linestyle='--', alpha=0.5, label='10mm Threshold')
    
    plt.yscale('log')
    plt.xlabel("Rainfall (mm)")
    plt.ylabel("Transformed Pareto Value (Log Scale)")
    plt.title("Transformation Check: Rainfall -> Pareto")
    plt.legend()
    plt.grid(True, alpha=0.3)

    # --- Plot 2: Histogram of Pareto Values ---
    plt.subplot(1, 2, 2)
    
    # We ignore the exact 1.0s (zeros/drizzle) to see the shape of the rest
    mask_active = model_df['Y_pareto'] > 1.0001
    active_data = model_df[mask_active]
    
    is_tail_active = active_data['RR'] > active_data['u_hat']
    
    plt.hist([active_data.loc[~is_tail_active, 'Y_pareto'], 
              active_data.loc[is_tail_active, 'Y_pareto']], 
             bins=np.logspace(0, 4, 50), 
             stacked=True, 
             color=['blue', 'red'], 
             label=['Bulk (>10mm)', 'Tail (>u_hat)'])
    
    plt.xscale('log')
    plt.xlabel("Pareto Value (Log Scale)")
    plt.ylabel("Count")
    plt.title(f"Distribution of Pareto Values (> 1.0)\n(Ignored {len(model_df) - len(active_data)} zeros/drizzle)")
    plt.legend()
    plt.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.show()

# Run the debug function
debug_pareto_transform(model_df)

# %% [markdown]
# ### Find extrems with risk func

# %%
# Create Space-Time Matrix
rr_matrix = model_df.pivot_table(index='Date', columns='NUM_POSTE', values='RR')
pareto_matrix = model_df.pivot_table(index='Date', columns='NUM_POSTE', values='Y_pareto')

# Filter Days: At least 5 stations must have >10mm rain
valid_days = (rr_matrix > 10).sum(axis=1) >= 5
pareto_matrix = pareto_matrix.loc[valid_days].fillna(1.0) # Fill missing/censored with 1.0

# Functional r_1 (Mean of Pareto values)
r1 = pareto_matrix.mean(axis=1)

# Functional r_xi (Mean of Power-Transformed Pareto)
r_xi = (np.power(pareto_matrix, xi_val).mean(axis=1)) ** (1/xi_val)

# Event Selection (80th Percentile)
u_r1 = r1.quantile(0.80)
u_rxi = r_xi.quantile(0.80)

extreme_days_r1 = r1[r1 > u_r1].index
extreme_days_rxi = r_xi[r_xi > u_rxi].index

print(f"Threshold r1: {u_r1:.2f} | Selected {len(extreme_days_r1)} events")
print(f"Threshold r_xi: {u_rxi:.2f} | Selected {len(extreme_days_rxi)} events")
# Out:
# Threshold r1: 1.23 | Selected 1259 events
# Threshold r_xi: 1.05 | Selected 1259 events

# %%
plt.figure(figsize=(10, 4))
plt.plot(r1.index, r1, label='$r_{\\xi}$ Score', color='steelblue', lw=0.5)

plt.axhline(u_r1, color='red', linestyle='--', 
            label=f'Threshold (80%): {u_r1:.2f}')

plt.scatter(extreme_days_r1, r1[extreme_days_r1], 
            color='red', s=10, alpha=0.6, label='Selected Extreme Events')

plt.yscale('log')
plt.title("Spatial Risk Functional ($r_{\\xi}$) Over Time")
plt.ylabel("Risk Score (Log Scale)")
plt.xlabel("Date")
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# ### empirical semivariogram

# %%
from scipy.spatial.distance import pdist, squareform
from sklearn.metrics.pairwise import haversine_distances
from tqdm import tqdm

# --- 1. Prepare Data for Variogram ---
# We need:
#   - Coordinates (LON, LAT) for distances
coords = model_df.groupby('NUM_POSTE')[['LON', 'LAT']].first().loc[pareto_matrix.columns].values
#   - Daily Temperature (temp_30d_avg) for the covariate for the extreme days
daily_temps = model_df.groupby('Date')['temp_30d_avg'].first().loc[extreme_days_r1]
#   - Pareto Data (Y_pareto) for the dependence measure
data_extremes = pareto_matrix.loc[extreme_days_r1]

# Transform to Log Scale (Brown-Resnick is Log-Gaussian)
log_data = np.log(data_extremes)

# --- 2. Calculate Distances (Haversine in km) ---
print("Computing Haversine Distances...")

coords_rad = np.radians(coords[:, [1, 0]])
dist_matrix_rad = haversine_distances(coords_rad) # radians distance on the sphere
dist_matrix_km = dist_matrix_rad * 6371 # Convert to km (Earth Radius ~ 6371 km)
dists = squareform(dist_matrix_km, checks=False)
print(f"Max distance between stations: {dists.max():.2f} km")

# --- 3. Compute Empirical Variogram (Binned) ---
print("Computing Empirical Variogram...")

# Define Bins
n_bins = 20
bins = np.linspace(0, dists.max(), n_bins + 1)
bin_centers = (bins[:-1] + bins[1:]) / 2

# Pre-calculate bin indices for the 1D distance array
bin_indices = np.digitize(dists, bins)
empirical_gamma_list = []
mean_temps = []

# Iterate over extreme days
for date in tqdm(log_data.index, total=len(log_data), desc="Creating semivariograms"):
    day_vals = log_data.loc[date].values
    day_temp = daily_temps.loc[date]
    
    # Calculate semi-variogram for this day: 0.5 * (Z(s1) - Z(s2))^2
    diffs = day_vals[:, None] - day_vals[None, :]
    sq_diffs = 0.5 * (diffs ** 2)
    sq_diffs_flat = squareform(sq_diffs, checks=False) # Flatten to 1D to match 'dists' shape
    
    # Aggregate by distance bin
    # We compute the mean variogram value for each distance bin for this day
    day_gamma = []
    for i in range(1, len(bins)):
        mask = bin_indices == i
        if np.any(mask):
            day_gamma.append(sq_diffs_flat[mask].mean())
        else:
            day_gamma.append(np.nan)
            
    empirical_gamma_list.append(day_gamma)
    mean_temps.append(day_temp)

# Convert to arrays
empirical_gamma_matrix = np.array(empirical_gamma_list) # Shape: (n_days, n_bins)
temp_vector = np.array(mean_temps)

# Fill NaNs (empty bins) with 0
empirical_gamma_matrix = np.nan_to_num(empirical_gamma_matrix)

print(f"Empirical Variogram computed for {len(empirical_gamma_matrix)} days.")
# Out:
# Computing Haversine Distances...
# Max distance between stations: 271.73 km
# Computing Empirical Variogram...
# Creating semivariograms: 100%|██████████| 1259/1259 [00:08<00:00, 145.28it/s]
# Empirical Variogram computed for 1259 days.

# %% [markdown]
# ### Fit spatial dependance model

# %% [markdown]
# truncate large distances as to few stations

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import least_squares

# --- 1. Define Corrected Model & Residuals ---
def theoretical_variogram(h, temp, params):
    nu, lambda0, lambda1 = params
    range_param = np.exp(lambda0 + lambda1 * temp)
    return (h / range_param) ** nu

def residual_func(params, h_bins, temps, empirical_matrix):
    nu, lambda0, lambda1 = params
    range_params = np.exp(lambda0 + lambda1 * temps[:, None])
    predicted = (h_bins[None, :] / range_params) ** nu
    
    valid_mask = empirical_matrix > 0
    diff = predicted[valid_mask] - empirical_matrix[valid_mask]
    return diff

dates = extreme_days_r1

def get_season(month):
    if month in [12, 1, 2]: return 'Winter'
    elif month in [3, 4, 5]: return 'Spring'
    elif month in [6, 7, 8]: return 'Summer'
    else: return 'Fall'

seasons = ['Winter', 'Spring', 'Summer', 'Fall']

# --- Configuration ---
# Truncate analysis at 200km (sufficient for mesoscale storms)
MAX_LAG = 175 
MIN_LAG = 30
N_BINS = 15

# Re-define bins up to MAX_LAG only
bins = np.linspace(MIN_LAG, MAX_LAG, N_BINS + 1)
bin_centers = (bins[:-1] + bins[1:]) / 2

# Recalculate bin indices for the new range
# Indices > N_BINS correspond to distances > MAX_LAG (ignored)
bin_indices = np.digitize(dists, bins)

# --- 1. Re-compute Empirical Variogram for Truncated Bins ---
# We need to re-aggregate because the previous matrix included far-away bins
empirical_gamma_list_trunc = []
valid_days_indices = []

print(f"Re-binning variogram up to {MAX_LAG} km...")

for idx, date in enumerate(log_data.index):
    day_vals = log_data.loc[date].values
    
    # Pairwise differences
    diffs = day_vals[:, None] - day_vals[None, :]
    sq_diffs = 0.5 * (diffs ** 2)
    sq_diffs_flat = squareform(sq_diffs, checks=False)
    
    day_gamma = []
    has_data = False
    
    for i in range(1, len(bins)):
        mask = bin_indices == i
        if np.any(mask):
            day_gamma.append(sq_diffs_flat[mask].mean())
            has_data = True
        else:
            day_gamma.append(np.nan)
    
    if has_data:
        empirical_gamma_list_trunc.append(day_gamma)
        valid_days_indices.append(idx)

empirical_gamma_matrix_trunc = np.array(empirical_gamma_list_trunc)
# Filter temp vector to match valid days
t_vector_trunc = temp_vector[valid_days_indices]

# --- 2. Count Pairs per Bin (Diagnostic) ---
# Count how many station pairs exist in each distance bin
pair_counts = [np.sum(bin_indices == i) for i in range(1, len(bins))]

# --- 3. Refit Model on Truncated Data ---
dates_trunc = dates[valid_days_indices]
seasonal_fits = {}

# Setup Plot grid: Top row = Variograms, Bottom row = Pair Counts
fig = plt.figure(figsize=(14, 8))
gs = fig.add_gridspec(2, 2, height_ratios=[3, 1])

seasons = ['Winter', 'Spring', 'Summer', 'Fall']

print("-" * 75)
print(f"{'Season':<10} | {'nu':<8} | {'lambda0':<8} | {'lambda1':<8} | {'Success'}")
print("-" * 75)

for i, season in enumerate(seasons):
    # Filter for Season
    season_mask = dates_trunc.month.map(get_season) == season
    if season_mask.sum() < 10: continue
        
    y_season = empirical_gamma_matrix_trunc[season_mask]
    t_season = t_vector_trunc[season_mask]
    
    # Fit Model
    x0 = [0.7, 3.5, -0.05] # Adjusted guess
    bounds = ([0.05, -np.inf, -np.inf], [1.99, np.inf, np.inf])
    
    res = least_squares(residual_func, x0, bounds=bounds, 
                        args=(bin_centers, t_season, y_season))
    
    nu, l0, l1 = res.x
    seasonal_fits[season] = [nu, l0, l1]
    print(f"{season:<10} | {nu:.4f}   | {l0:.4f}   | {l1:.4f}   | {res.success}")
    
    # --- Visualization ---
    # Variogram Plot
    # Actually let's just do 2x2 grid of combined plots to save space
    ax = fig.add_subplot(2, 2, i+1)
    
    # Plot Empirical
    t_low_mask = t_season < np.percentile(t_season, 25)
    t_high_mask = t_season > np.percentile(t_season, 75)
    
    mean_low = np.nanmean(y_season[t_low_mask], axis=0)
    mean_high = np.nanmean(y_season[t_high_mask], axis=0)
    
    # Twin axis for Histogram
    ax_hist = ax.twinx()
    ax_hist.bar(bin_centers, pair_counts, width=bins[1]-bins[0], alpha=0.1, color='gray', label='Pair Counts')
    ax_hist.set_axis_off() # Hide counts scale, just showing density shape
    
    # Main Plots
    ax.scatter(bin_centers, mean_low, c='blue', s=20, label='Low Temp')
    ax.scatter(bin_centers, mean_high, c='red', s=20, label='High Temp')
    
    # Model
    t_low = t_season[t_low_mask].mean()
    t_high = t_season[t_high_mask].mean()
    ax.plot(bin_centers, theoretical_variogram(bin_centers, t_low, res.x), c='blue', ls='--')
    ax.plot(bin_centers, theoretical_variogram(bin_centers, t_high, res.x), c='red', ls='--')
    
    ax.set_title(f"{season} ($\lambda_1={l1:.4f}$)")
    ax.set_xlabel("Distance (km)")
    if i % 2 == 0: ax.set_ylabel("Semivariogram $\gamma(h)$")
    
    # Add text annotation for pair drop-off
    if i == 0:
        ax.text(0.05, 0.95, "Gray bars = Number of pairs", transform=ax.transAxes, color='gray', fontsize=9)

plt.suptitle(f"Spatial Dependence (Truncated at {MAX_LAG}km)", fontsize=16)
plt.tight_layout()
plt.subplots_adjust(top=0.90)
plt.show()
# Out:
# Re-binning variogram up to 175 km...
# ---------------------------------------------------------------------------
# Season     | nu       | lambda0  | lambda1  | Success
# ---------------------------------------------------------------------------
# Winter     | 0.1447   | 8.0703   | 0.0201   | True
# Spring     | 0.0986   | 11.1909   | 0.0494   | True
# Summer     | 0.0941   | 12.4233   | 0.1337   | True
# Fall       | 0.1245   | 8.4800   | 0.0455   | True

# %% [markdown]
# ### Tail correlation range

# %%
from scipy.stats import norm

def plot_effective_range(seasonal_fits, temp_data=None):
    """
    Plots the Effective Range (distance where tail correlation = 0.05) vs Temperature.
    """
    # 1. Calculate Critical Gamma Value for chi = 0.05
    # chi = 2 * (1 - Phi(sqrt(gamma/2))) = 0.05
    # Phi(sqrt(gamma/2)) = 1 - 0.025 = 0.975
    # sqrt(gamma/2) = quantile(0.975) approx 1.96
    z_score = norm.ppf(0.975)
    gamma_crit = 2 * (z_score ** 2) # approx 7.68
    
    print(f"Critical Variogram Value for chi=0.05: {gamma_crit:.4f}")

    # 2. Setup Plot
    plt.figure(figsize=(10, 6))
    
    seasons = ['Winter', 'Spring', 'Summer', 'Fall']
    colors = {'Winter': 'purple', 'Spring': 'green', 'Summer': 'orange', 'Fall': 'brown'}
    
    # Define Temperature Range for plotting (e.g., -5C to 35C)
    if temp_data is not None:
        t_min, t_max = temp_data.min(), temp_data.max()
    else:
        t_min, t_max = -5, 30
    
    t_grid = np.linspace(t_min, t_max, 100)
    
    for season in seasons:
        if season not in seasonal_fits:
            continue
            
        params = seasonal_fits[season]
        nu, lambda0, lambda1 = params
        
        # Calculate Effective Range
        # h_eff = lambda(T) * (gamma_crit)^(1/nu)
        # lambda(T) = exp(lambda0 + lambda1 * T)
        
        range_param = np.exp(lambda0 + lambda1 * t_grid)
        scaling_factor = gamma_crit ** (1 / nu)
        
        h_eff = range_param * scaling_factor
        
        # Plot
        plt.plot(t_grid, h_eff, lw=3, color=colors[season], label=f"{season} ($\lambda_1={lambda1:.3f}$)")
        
        # Add marker for mean temp of that season if available?
        # (Skipping for cleaner plot)

    # 3. Formatting
    plt.title("Effective Tail-Correlation Range vs Temperature\n(Distance where $\chi = 0.05$)", fontsize=14)
    plt.xlabel("Temperature ($^\circ$C)", fontsize=12)
    plt.ylabel("Effective Range (km)", fontsize=12)
    plt.yscale('log') # Log scale helps distinguish the scales
    plt.grid(True, which="both", ls="-", alpha=0.2)
    plt.legend(title="Season")
    
    # Add Limits if needed to match paper style (e.g. 0 to 400km)
    # plt.ylim(0, 500) 
    
    plt.tight_layout()
    plt.show()

# Run the plot
# Assumes 'seasonal_fits' was populated in the previous cell
# Assumes 'temp_vector' exists from previous step
plot_effective_range(seasonal_fits, temp_vector)
# Out:
# Critical Variogram Value for chi=0.05: 7.6829

# %% [markdown]
# ### Fit on raw data

# %%
import numpy as np
from scipy.optimize import least_squares
import matplotlib.pyplot as plt

# --- 1. Subsampling Configuration ---
# 5 million points is enough for extreme precision but fits easily in 1GB RAM
TARGET_N_SAMPLES = 5_000_000 

# Check total size
total_pairs = len(Y_obs)
print(f"Total available pairs: {total_pairs:,}")

if total_pairs > TARGET_N_SAMPLES:
    print(f"Subsampling to {TARGET_N_SAMPLES:,} pairs for efficiency...")
    # Generate random indices
    rng = np.random.default_rng(42)
    indices = rng.choice(total_pairs, size=TARGET_N_SAMPLES, replace=False)
    
    # Subset the huge arrays
    X_dist_sub = X_dist[indices]
    X_temp_sub = X_temp[indices]
    Y_obs_sub = Y_obs[indices]
    dates_expanded_sub = dates_expanded[indices]
else:
    # Use everything if small
    X_dist_sub = X_dist
    X_temp_sub = X_temp
    Y_obs_sub = Y_obs
    dates_expanded_sub = dates_expanded

print(f"Final dataset size: {len(Y_obs_sub):,} pairs")

# --- 2. Define Direct Residual Function ---
def residual_direct(params, dists, temps, observed_diffs):
    nu, lambda0, lambda1 = params
    
    # Theoretical Variogram
    range_params = np.exp(lambda0 + lambda1 * temps)
    predicted = (dists / range_params) ** nu
    
    # Residual
    return predicted - observed_diffs

# --- 3. Seasonal Fitting Loop ---
seasonal_fits = {}
seasons = ['Winter', 'Spring', 'Summer', 'Fall']
vis_bins = np.linspace(MIN_LAG, MAX_LAG, 10)
vis_bin_centers = (vis_bins[:-1] + vis_bins[1:]) / 2

fig, axs = plt.subplots(2, 2, figsize=(14, 10))
axs = axs.flatten()

print("-" * 75)
print(f"{'Season':<10} | {'Pairs':<8} | {'nu':<8} | {'lambda0':<8} | {'lambda1':<8} | {'Success'}")
print("-" * 75)

for i, season in enumerate(seasons):
    # Filter using the SUBSAMPLED arrays
    # Re-derive months from the dates array
    months = dates_expanded_sub.month
    
    if season == 'Winter': mask = np.isin(months, [12, 1, 2])
    elif season == 'Spring': mask = np.isin(months, [3, 4, 5])
    elif season == 'Summer': mask = np.isin(months, [6, 7, 8])
    else: mask = np.isin(months, [9, 10, 11])
    
    dist_s = X_dist_sub[mask]
    temp_s = X_temp_sub[mask]
    y_s = Y_obs_sub[mask]
    
    if len(y_s) < 1000:
        print(f"{season:<10} | {len(y_s):<8} | Not enough data")
        continue
        
    # Fit
    # Tighter bounds on nu [0.2, 1.5] usually help stability
    x0 = [0.7, 3.5, -0.05]
    bounds = ([0.2, -np.inf, -np.inf], [1.5, np.inf, np.inf])
    
    res = least_squares(residual_direct, x0, bounds=bounds, 
                        args=(dist_s, temp_s, y_s),
                        loss='soft_l1', f_scale=0.1)
    
    seasonal_fits[season] = res.x
    nu, l0, l1 = res.x
    print(f"{season:<10} | {len(y_s):<8} | {nu:.4f}   | {l0:.4f}   | {l1:.4f}   | {res.success}")
    
    # Visualization (Plotting mean of cloud bins for clarity)
    ax = axs[i]
    
    bin_idxs = np.digitize(dist_s, vis_bins)
    
    # Calculate binned means for Low vs High Temp (within this season)
    t_low_mask = temp_s < np.percentile(temp_s, 25)
    t_high_mask = temp_s > np.percentile(temp_s, 75)
    
    mean_low = []
    mean_high = []
    
    for b in range(1, len(vis_bins)):
        # Compute mean only if we have data in that bin
        # (This avoids nan warnings)
        mask_low = (t_low_mask) & (bin_idxs == b)
        mask_high = (t_high_mask) & (bin_idxs == b)
        
        val_low = y_s[mask_low].mean() if np.any(mask_low) else np.nan
        val_high = y_s[mask_high].mean() if np.any(mask_high) else np.nan
        
        mean_low.append(val_low)
        mean_high.append(val_high)
    
    ax.scatter(vis_bin_centers, mean_low, c='blue', s=40, label='Mean Cloud (Cool)')
    ax.scatter(vis_bin_centers, mean_high, c='red', s=40, label='Mean Cloud (Warm)')
    
    # Plot Fitted Model
    # We use the mean temp of the subset to draw the lines
    t_low_val = temp_s[t_low_mask].mean()
    t_high_val = temp_s[t_high_mask].mean()
    
    def theory(h, t, p): return (h / np.exp(p[1] + p[2]*t))**p[0]
    
    ax.plot(vis_bin_centers, theory(vis_bin_centers, t_low_val, res.x), c='blue', ls='--', lw=2)
    ax.plot(vis_bin_centers, theory(vis_bin_centers, t_high_val, res.x), c='red', ls='--', lw=2)
    
    ax.set_title(f"{season} ($\lambda_1={l1:.4f}$)")
    if i % 2 == 0: ax.set_ylabel("Semivariogram $\gamma(h)$")

plt.suptitle("Direct Cloud Fit (Subsampled 5M Points)", fontsize=16)
plt.tight_layout()
plt.subplots_adjust(top=0.90)
plt.show()
# Out:
# ...
# Total pairwise observations: 114348675
# ---------------------------------------------------------------------------
# Season     | Pairs    | nu       | lambda0  | lambda1  | Success
# ---------------------------------------------------------------------------
