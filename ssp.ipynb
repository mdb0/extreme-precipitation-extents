# %%
import os
import joblib
import pandas as pd

# %%
print("Loading models...")
gam_path = "processed_data/gam_model.pth"
gam_loaded = joblib.load(gam_path)
print(f"  - GAM loaded from: {gam_path}")

gp_path = "processed_data/gp_model.pth"
gp_loaded = joblib.load(gp_path)
print(f"  - GP Estimator loaded from: {gp_path}")

grid = pd.read_csv(
                "processed_data/grid.csv.gz", 
                compression='gzip', 
                sep=',',  
                encoding='utf-8', 
                low_memory=False
            )
print("  - Load grid points")

hist_temp = pd.read_csv(
                "processed_data/basin_wide_temperature_covariate.csv.gz", 
                compression='gzip', 
                sep=',',  
                encoding='utf-8', 
                low_memory=False
            )
print("  - Load history of average temperature")
# Out:
# Loading models...
#   - GAM loaded from: processed_data/gam_model.pth
#   - GP Estimator loaded from: processed_data/gp_model.pth
#   - Load grid points
#   - Load history of average temperature
